# %% [markdown]
# # OPER 610
# ## Problem 1.6 (Phase 2)
# ### Brandon Hosley

# %% [markdown]
# ## Preparation

# %%
import pyomo.environ as pyo
model = pyo.AbstractModel()

# %% [markdown]
# ## Definitions
#
# **Sets**:
# $$\begin{align*}
# 	W &= \{1,2,\ldots,8\}\hspace{19ex} & &:\  \text{Week } w \\
# 	C &= \{\text{Swiss cheese},\, \text{Sharp cheese}\}\ & &:\  \text{Cheese } c
# \end{align*}$$

# %%
model.C = pyo.Set()
model.W = pyo.Set(ordered=True)

# %% [markdown]
# **Parameters**:
#
# $\tau_{c,w}$ : Entry in the $c$ cheese row, $w$ week column of the original demand table </br>
# $\rho_c$ : Lbs of cheese $c$ that an employee can produce per hour </br>
# $\omega$ : Hours in the work week </br>
# $\alpha$ : Number of employees at the beginning of the period </br>
# $\gamma$ : Desired employee growth </br>
#
# $e_w$ : Experienced employees in week $w$ </br>
# $i_{c,w}$ : Stored inventory of cheese $c$ at the end of week $w$ </br>
# $d_{c,w}$ : Demand of cheese $c$ in week $w$ (Change in units, described below)

# %%
model.lbs_hour = pyo.Param(model.C)
model.hours_week = pyo.Param()
model.initial_staff = pyo.Param()
model.desired_growth = pyo.Param()

model.demand = pyo.Param(model.C, model.W)
model.d = pyo.Param(model.C, model.W, mutable=True)

# %% [markdown]
# Early constraint:
# $$\begin{align*}
# 	t,x,d &\geq0 & &\text{(Non-negativity)} \\
# \end{align*}$$

# %%
model.x = pyo.Var(model.C, model.W, domain=pyo.NonNegativeReals)
model.i = pyo.Var(model.C, model.W, domain=pyo.NonNegativeReals)
model.t = pyo.Var(model.W, domain=pyo.NonNegativeIntegers)
model.e = pyo.Var(model.W, domain=pyo.PositiveIntegers)

# %% [markdown]
# ## Objective Function
#
# $$\min\quad \sum_{w\in W}e_w$$

# %%
def obj_expression(m):
    return sum(m.e[w] for w in m.W)
model.objectivefunction = pyo.Objective(rule = obj_expression)

# %% [markdown]
# ## Constraints
#
# $$\begin{align*}
# \left\lceil\frac{1}{3}t_w \right\rceil + \left\lceil\frac{1}{3}t_{w-1} \right\rceil
# 	+ \sum_{c\in C}x_{c,w} &\leq e_w & &\forall\ w\in W & &\text{(Labor availability)} \\
# 	e_{w-1} + t_{w-2} &= e_w & &\forall w\in W\backslash\{1,2\} & &\text{(Trainees become experienced)} \\
# 	\sum_{w\in W}t_w &= \gamma && & &\text{(Meeting hiring goal)} \\
# 	x_{c,w} + i_{c,w-1} - i_{c,w} &= d_{c,w} & &\forall\ c\in C, w\in W & &\text{(Production, inventory, and demand)} \\
# 	i_{c,w-1} &\leq d_{c,w} & &\forall\ c\in C, w\in W & &\text{(Prevent production of wasted cheese)}
# \end{align*}$$

# %%
def labor_availability(m,w):
    if w == 1:
        return (m.t[w]/3 + sum(m.x[c,w] for c in m.C)) <= m.e[w] 
    else:
        return (m.t[w]/3 + m.t[w-1]/3 + sum(m.x[c,w] for c in m.C)) <= m.e[w]     
model.LaborConstraint = pyo.Constraint(model.W, rule = labor_availability)

def hiring_goal(m):
    return sum(m.t[w] for w in m.W) == m.desired_growth
model.HiringConstraint = pyo.Constraint(rule = hiring_goal)

def training_completion(m,w):
    if((w == 1) or (w == 2)):
        return m.e[1] == m.e[2]
    else:
        return (m.e[w-1] + m.t[w-2]) == m.e[w]
model.TrainingConstraint = pyo.Constraint(model.W, rule = training_completion)

def cheese_pipeline(m,c,w): 
    if w == 1:
        return (m.x[c,w] - m.i[c,w]) == m.d[c,w]
    else:
        return (m.x[c,w] + m.i[c,w-1] - m.i[c,w]) == m.d[c,w]
model.ProductionConstraint = pyo.Constraint(model.C, model.W, rule = cheese_pipeline)
    
def throttle_cheese(m,c,w):
    return pyo.Constraint.Skip if w == 1 else m.i[c,w-1] <= m.d[c,w]
model.SpoilageConstraint = pyo.Constraint(model.C, model.W, rule = throttle_cheese)

# %% [markdown]
# **Unit Conversion**:
# $$ d_{c,w} = \frac{1000\tau_{c,w}}{\rho_c \omega} \qquad \forall\ c\in C, w\in W.  $$
# **Final Constraints**:
# $$\begin{align*}
# 	e_1 &=\alpha & &\text{(Initial staff)} \\
# 	t_8 &= 0 & &\text{(Insufficient training time}
# \end{align*}$$

# %%
inst=model.create_instance('cheese.dat')

for c in inst.C:
    for w in inst.W:
        inst.d[c,w] = ((inst.demand[c,w] * 1000) / (inst.hours_week * inst.lbs_hour[c]))
        
inst.e[1].fix(inst.initial_staff)
inst.t[8].fix(0)
        
inst.pprint()
# Out:
# 8 Set Declarations
#     C : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    2 : {'sharp', 'swiss'}
#     ProductionConstraint_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain : Size : Members
#         None :     2 :    C*W :   16 : {('sharp', 1), ('sharp', 2), ('sharp', 3), ('sharp', 4), ('sharp', 5), ('sharp', 6), ('sharp', 7), ('sharp', 8), ('swiss', 1), ('swiss', 2), ('swiss', 3), ('swiss', 4), ('swiss', 5), ('swiss', 6), ('swiss', 7), ('swiss', 8)}
#     SpoilageConstraint_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain : Size : Members
#         None :     2 :    C*W :   16 : {('sharp', 1), ('sharp', 2), ('sharp', 3), ('sharp', 4), ('sharp', 5), ('sharp', 6), ('sharp', 7), ('sharp', 8), ('swiss', 1), ('swiss', 2), ('swiss', 3), ('swiss', 4), ('swiss', 5), ('swiss', 6), ('swiss', 7), ('swiss', 8)}
#     W : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    8 : {1, 2, 3, 4, 5, 6, 7, 8}
#     d_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain : Size : Members
#         None :     2 :    C*W :   16 : {('sharp', 1), ('sharp', 2), ('sharp', 3), ('sharp', 4), ('sharp', 5), ('sharp', 6), ('sharp', 7), ('sharp', 8), ('swiss', 1), ('swiss', 2), ('swiss', 3), ('swiss', 4), ('swiss', 5), ('swiss', 6), ('swiss', 7), ('swiss', 8)}
#     demand_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain : Size : Members
#         None :     2 :    C*W :   16 : {('sharp', 1), ('sharp', 2), ('sharp', 3), ('sharp', 4), ('sharp', 5), ('sharp', 6), ('sharp', 7), ('sharp', 8), ('swiss', 1), ('swiss', 2), ('swiss', 3), ('swiss', 4), ('swiss', 5), ('swiss', 6), ('swiss', 7), ('swiss', 8)}
#     i_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain : Size : Members
#         None :     2 :    C*W :   16 : {('sharp', 1), ('sharp', 2), ('sharp', 3), ('sharp', 4), ('sharp', 5), ('sharp', 6), ('sharp', 7), ('sharp', 8), ('swiss', 1), ('swiss', 2), ('swiss', 3), ('swiss', 4), ('swiss', 5), ('swiss', 6), ('swiss', 7), ('swiss', 8)}
#     x_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain : Size : Members
#         None :     2 :    C*W :   16 : {('sharp', 1), ('sharp', 2), ('sharp', 3), ('sharp', 4), ('sharp', 5), ('sharp', 6), ('sharp', 7), ('sharp', 8), ('swiss', 1), ('swiss', 2), ('swiss', 3), ('swiss', 4), ('swiss', 5), ('swiss', 6), ('swiss', 7), ('swiss', 8)}
#
# 6 Param Declarations
#     d : Size=16, Index=d_index, Domain=Any, Default=None, Mutable=True
#         Key          : Value
#         ('sharp', 1) :               20.0
#         ('sharp', 2) :               20.0
#         ('sharp', 3) :               25.0
#         ('sharp', 4) :               20.0
#         ('sharp', 5) :               30.0
#         ('sharp', 6) :               32.5
#         ('sharp', 7) :               30.0
#         ('sharp', 8) :               30.0
#         ('swiss', 1) : 22.916666666666668
#         ('swiss', 2) :               25.0
#         ('swiss', 3) : 27.083333333333332
#         ('swiss', 4) :               37.5
#         ('swiss', 5) : 29.166666666666668
#         ('swiss', 6) :               37.5
#         ('swiss', 7) : 41.666666666666664
#         ('swiss', 8) : 41.666666666666664
#     demand : Size=16, Index=demand_index, Domain=Any, Default=None, Mutable=False
#         Key          : Value
#         ('sharp', 1) :     8
#         ('sharp', 2) :     8
#         ('sharp', 3) :    10
#         ('sharp', 4) :     8
#         ('sharp', 5) :    12
#         ('sharp', 6) :    13
#         ('sharp', 7) :    12
#         ('sharp', 8) :    12
#         ('swiss', 1) :    11
#         ('swiss', 2) :    12
#         ('swiss', 3) :    13
#         ('swiss', 4) :    18
#         ('swiss', 5) :    14
#         ('swiss', 6) :    18
#         ('swiss', 7) :    20
#         ('swiss', 8) :    20
#     desired_growth : Size=1, Index=None, Domain=Any, Default=None, Mutable=False
#         Key  : Value
#         None :    30
#     hours_week : Size=1, Index=None, Domain=Any, Default=None, Mutable=False
#         Key  : Value
#         None :    40
#     initial_staff : Size=1, Index=None, Domain=Any, Default=None, Mutable=False
#         Key  : Value
#         None :    60
#     lbs_hour : Size=2, Index=C, Domain=Any, Default=None, Mutable=False
#         Key   : Value
#         sharp :    10
#         swiss :    12
#
# 4 Var Declarations
#     e : Size=8, Index=W
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           1 :     1 :    60 :  None :  True : False : PositiveIntegers
#           2 :     1 :  None :  None : False :  True : PositiveIntegers
#           3 :     1 :  None :  None : False :  True : PositiveIntegers
#           4 :     1 :  None :  None : False :  True : PositiveIntegers
#           5 :     1 :  None :  None : False :  True : PositiveIntegers
#           6 :     1 :  None :  None : False :  True : PositiveIntegers
#           7 :     1 :  None :  None : False :  True : PositiveIntegers
#           8 :     1 :  None :  None : False :  True : PositiveIntegers
#     i : Size=16, Index=i_index
#         Key          : Lower : Value : Upper : Fixed : Stale : Domain
#         ('sharp', 1) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('sharp', 2) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('sharp', 3) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('sharp', 4) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('sharp', 5) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('sharp', 6) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('sharp', 7) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('sharp', 8) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('swiss', 1) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('swiss', 2) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('swiss', 3) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('swiss', 4) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('swiss', 5) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('swiss', 6) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('swiss', 7) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('swiss', 8) :     0 :  None :  None : False :  True : NonNegativeReals
#     t : Size=8, Index=W
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           1 :     0 :  None :  None : False :  True : NonNegativeIntegers
#           2 :     0 :  None :  None : False :  True : NonNegativeIntegers
#           3 :     0 :  None :  None : False :  True : NonNegativeIntegers
#           4 :     0 :  None :  None : False :  True : NonNegativeIntegers
#           5 :     0 :  None :  None : False :  True : NonNegativeIntegers
#           6 :     0 :  None :  None : False :  True : NonNegativeIntegers
#           7 :     0 :  None :  None : False :  True : NonNegativeIntegers
#           8 :     0 :     0 :  None :  True : False : NonNegativeIntegers
#     x : Size=16, Index=x_index
#         Key          : Lower : Value : Upper : Fixed : Stale : Domain
#         ('sharp', 1) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('sharp', 2) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('sharp', 3) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('sharp', 4) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('sharp', 5) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('sharp', 6) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('sharp', 7) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('sharp', 8) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('swiss', 1) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('swiss', 2) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('swiss', 3) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('swiss', 4) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('swiss', 5) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('swiss', 6) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('swiss', 7) :     0 :  None :  None : False :  True : NonNegativeReals
#         ('swiss', 8) :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     objectivefunction : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize : e[1] + e[2] + e[3] + e[4] + e[5] + e[6] + e[7] + e[8]
#
# 5 Constraint Declarations
#     HiringConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                                  : Upper : Active
#         None :  30.0 : t[1] + t[2] + t[3] + t[4] + t[5] + t[6] + t[7] + t[8] :  30.0 :   True
#     LaborConstraint : Size=8, Index=W, Active=True
#         Key : Lower : Body                                                                               : Upper : Active
#           1 :  -Inf :                           x[sharp,1] + x[swiss,1] + 0.3333333333333333*t[1] - e[1] :   0.0 :   True
#           2 :  -Inf : 0.3333333333333333*t[2] + 0.3333333333333333*t[1] + x[sharp,2] + x[swiss,2] - e[2] :   0.0 :   True
#           3 :  -Inf : 0.3333333333333333*t[3] + 0.3333333333333333*t[2] + x[sharp,3] + x[swiss,3] - e[3] :   0.0 :   True
#           4 :  -Inf : 0.3333333333333333*t[4] + 0.3333333333333333*t[3] + x[sharp,4] + x[swiss,4] - e[4] :   0.0 :   True
#           5 :  -Inf : 0.3333333333333333*t[5] + 0.3333333333333333*t[4] + x[sharp,5] + x[swiss,5] - e[5] :   0.0 :   True
#           6 :  -Inf : 0.3333333333333333*t[6] + 0.3333333333333333*t[5] + x[sharp,6] + x[swiss,6] - e[6] :   0.0 :   True
#           7 :  -Inf : 0.3333333333333333*t[7] + 0.3333333333333333*t[6] + x[sharp,7] + x[swiss,7] - e[7] :   0.0 :   True
#           8 :  -Inf : 0.3333333333333333*t[8] + 0.3333333333333333*t[7] + x[sharp,8] + x[swiss,8] - e[8] :   0.0 :   True
#     ProductionConstraint : Size=16, Index=ProductionConstraint_index, Active=True
#         Key          : Lower      : Body                                 : Upper      : Active
#         ('sharp', 1) : d[sharp,1] :              x[sharp,1] - i[sharp,1] : d[sharp,1] :   True
#         ('sharp', 2) : d[sharp,2] : x[sharp,2] + i[sharp,1] - i[sharp,2] : d[sharp,2] :   True
#         ('sharp', 3) : d[sharp,3] : x[sharp,3] + i[sharp,2] - i[sharp,3] : d[sharp,3] :   True
#         ('sharp', 4) : d[sharp,4] : x[sharp,4] + i[sharp,3] - i[sharp,4] : d[sharp,4] :   True
#         ('sharp', 5) : d[sharp,5] : x[sharp,5] + i[sharp,4] - i[sharp,5] : d[sharp,5] :   True
#         ('sharp', 6) : d[sharp,6] : x[sharp,6] + i[sharp,5] - i[sharp,6] : d[sharp,6] :   True
#         ('sharp', 7) : d[sharp,7] : x[sharp,7] + i[sharp,6] - i[sharp,7] : d[sharp,7] :   True
#         ('sharp', 8) : d[sharp,8] : x[sharp,8] + i[sharp,7] - i[sharp,8] : d[sharp,8] :   True
#         ('swiss', 1) : d[swiss,1] :              x[swiss,1] - i[swiss,1] : d[swiss,1] :   True
#         ('swiss', 2) : d[swiss,2] : x[swiss,2] + i[swiss,1] - i[swiss,2] : d[swiss,2] :   True
#         ('swiss', 3) : d[swiss,3] : x[swiss,3] + i[swiss,2] - i[swiss,3] : d[swiss,3] :   True
#         ('swiss', 4) : d[swiss,4] : x[swiss,4] + i[swiss,3] - i[swiss,4] : d[swiss,4] :   True
#         ('swiss', 5) : d[swiss,5] : x[swiss,5] + i[swiss,4] - i[swiss,5] : d[swiss,5] :   True
#         ('swiss', 6) : d[swiss,6] : x[swiss,6] + i[swiss,5] - i[swiss,6] : d[swiss,6] :   True
#         ('swiss', 7) : d[swiss,7] : x[swiss,7] + i[swiss,6] - i[swiss,7] : d[swiss,7] :   True
#         ('swiss', 8) : d[swiss,8] : x[swiss,8] + i[swiss,7] - i[swiss,8] : d[swiss,8] :   True
#     SpoilageConstraint : Size=14, Index=SpoilageConstraint_index, Active=True
#         Key          : Lower : Body       : Upper      : Active
#         ('sharp', 2) :  -Inf : i[sharp,1] : d[sharp,2] :   True
#         ('sharp', 3) :  -Inf : i[sharp,2] : d[sharp,3] :   True
#         ('sharp', 4) :  -Inf : i[sharp,3] : d[sharp,4] :   True
#         ('sharp', 5) :  -Inf : i[sharp,4] : d[sharp,5] :   True
#         ('sharp', 6) :  -Inf : i[sharp,5] : d[sharp,6] :   True
#         ('sharp', 7) :  -Inf : i[sharp,6] : d[sharp,7] :   True
#         ('sharp', 8) :  -Inf : i[sharp,7] : d[sharp,8] :   True
#         ('swiss', 2) :  -Inf : i[swiss,1] : d[swiss,2] :   True
#         ('swiss', 3) :  -Inf : i[swiss,2] : d[swiss,3] :   True
#         ('swiss', 4) :  -Inf : i[swiss,3] : d[swiss,4] :   True
#         ('swiss', 5) :  -Inf : i[swiss,4] : d[swiss,5] :   True
#         ('swiss', 6) :  -Inf : i[swiss,5] : d[swiss,6] :   True
#         ('swiss', 7) :  -Inf : i[swiss,6] : d[swiss,7] :   True
#         ('swiss', 8) :  -Inf : i[swiss,7] : d[swiss,8] :   True
#     TrainingConstraint : Size=8, Index=W, Active=True
#         Key : Lower : Body               : Upper : Active
#           1 :   0.0 :        e[1] - e[2] :   0.0 :   True
#           2 :   0.0 :        e[1] - e[2] :   0.0 :   True
#           3 :   0.0 : e[2] + t[1] - e[3] :   0.0 :   True
#           4 :   0.0 : e[3] + t[2] - e[4] :   0.0 :   True
#           5 :   0.0 : e[4] + t[3] - e[5] :   0.0 :   True
#           6 :   0.0 : e[5] + t[4] - e[6] :   0.0 :   True
#           7 :   0.0 : e[6] + t[5] - e[7] :   0.0 :   True
#           8 :   0.0 : e[7] + t[6] - e[8] :   0.0 :   True
#
# 24 Declarations: C W lbs_hour hours_week initial_staff desired_growth demand_index demand d_index d x_index x i_index i t e objectivefunction LaborConstraint HiringConstraint TrainingConstraint ProductionConstraint_index ProductionConstraint SpoilageConstraint_index SpoilageConstraint

# %% [markdown]
# ## Solve

# %%
results=pyo.SolverFactory('glpk').solve(inst)

for w in inst.W.value:
    print(' week ', w, ':')
    print('    ', inst.t[w].value, ' new hires.')
    print('    ', inst.e[w].value, ' trained employees.')
    for c in inst.C.value:
        print('        ', c,' :', inst.x[c,w].value)
print('value :', inst.objectivefunction.expr())
# Out:
#  week  1 :
#      0.0  new hires.
#      60  trained employees.
#          sharp  : 37.0833333333333
#          swiss  : 22.9166666666667
#  week  2 :
#      0.0  new hires.
#      60.0  trained employees.
#          sharp  : 27.9166666666667
#          swiss  : 32.0833333333333
#  week  3 :
#      0.0  new hires.
#      60.0  trained employees.
#          sharp  : 20.0
#          swiss  : 40.0
#  week  4 :
#      0.0  new hires.
#      60.0  trained employees.
#          sharp  : 30.0
#          swiss  : 30.0
#  week  5 :
#      5.0  new hires.
#      60.0  trained employees.
#          sharp  : 32.5
#          swiss  : 25.8333333333333
#  week  6 :
#      0.0  new hires.
#      60.0  trained employees.
#          sharp  : 30.0
#          swiss  : 28.3333333333333
#  week  7 :
#      25.0  new hires.
#      65.0  trained employees.
#          sharp  : 15.0
#          swiss  : 41.6666666666667
#  week  8 :
#      0  new hires.
#      65.0  trained employees.
#          sharp  : 15.0
#          swiss  : 41.6666666666667
# value : 490.0
